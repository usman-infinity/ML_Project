# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import seaborn as sns
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# !pip install numpy pandas seaborn matplotlib
# Out:
# Requirement already satisfied: numpy in e:\ml_project\venv\lib\site-packages (2.4.2)
# Requirement already satisfied: pandas in e:\ml_project\venv\lib\site-packages (3.0.1)
# Requirement already satisfied: seaborn in e:\ml_project\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in e:\ml_project\venv\lib\site-packages (3.10.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\ml_project\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in e:\ml_project\venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in e:\ml_project\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in e:\ml_project\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\ml_project\venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\ml_project\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in e:\ml_project\venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in e:\ml_project\venv\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in e:\ml_project\venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in e:\ml_project\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
